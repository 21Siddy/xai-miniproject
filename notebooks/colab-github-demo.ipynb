# %% [markdown]
# <a href="https://colab.research.google.com/github/21Siddy/xai-miniproject/blob/main/notebooks/colab-github-demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This Notebook is connected to GitHub
#
# To Use this notebook
# 1. open google colab
# 2. from the welcome page choose GitHub ![Screenshot 2025-05-03 120030.png](data:image/png;base64,...)
# 3. This link https://github.com/21Siddy might be useful
# 4. Choose notebooks/colab-github-demo.ipynb
# 5. Make any changes and then from File menu in Colab Save a copy in Github. This is basically push and commit.

# %% [markdown]
# If Everything working okay, just print your name followed by ok after this md cell.

# %% [markdown]
# Once I see print statements, I will create a separate drive and mount it so we can use mutag database
